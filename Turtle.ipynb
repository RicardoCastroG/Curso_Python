# %% [markdown]
# <a href="https://colab.research.google.com/github/RicardoCastroG/Curso_Python/blob/main/Turtle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #instalacion

# %%
# !pip3 install ColabTurtle

# %%
from ColabTurtle.Turtle import *

# %%
import ColabTurtle

# %%
help(ColabTurtle)
# Out:
# Help on package ColabTurtle:
#
# NAME
#     ColabTurtle
#
# PACKAGE CONTENTS
#     Turtle
#
# FILE
#     /usr/local/lib/python3.10/dist-packages/ColabTurtle/__init__.py

# %%
initializeTurtle(initial_speed=7)
color_list=["red","purple","blue","green","orange","yelow"]
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#
#         <g visibility=visible transform="rotate(360,400,250) translate(382, 232)">
# ...

# %% [markdown]
# #

# %%
initializeTurtle(initial_speed=7)
color_list=["red","purple","blue","green","orange","yelow"]
bgcolor("green")
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="green"/>
#
#         <g visibility=visible transform="rotate(360,400,250) translate(382, 232)">
# ...

# %%
initializeTurtle(initial_speed=7)
color_list=["red","purple","blue","green","orange","yelow"]
bgcolor("green")
for i in range(3):
  forward(200)
  left(120)
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="green"/>
#         <line x1="400" y1="250" x2="400.0" y2="50.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="50.0" x2="226.795" y2="150.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="226.795" y1="150.0" x2="400.0" y2="250.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/>
#         <g visibility=visible transform="rotate(360,400.0,250.0) translate(382.0, 232.0)">
# ...

# %%
initializeTurtle(initial_speed=7)
color_list=["red","purple","blue","green","orange","yelow"]
bgcolor("blue")

for i in range(4):
  forward(200)
  left(90)
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="blue"/>
#         <line x1="400" y1="250" x2="400.0" y2="50.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="50.0" x2="200.0" y2="50.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="200.0" y1="50.0" x2="200.0" y2="250.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="200.0" y1="250.0" x2="400.0" y2="250.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/>
#         <g visibility=visible transform="rotate(360,400.0,250.0) translate(382.0, 232.0)">
# ...

# %%
initializeTurtle(initial_speed=7)
color_list=["red","purple","blue","green","orange","yelow"]
bgcolor("blue")
setx(500)
for i in range(4):
  forward(200)
  left(90)
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="blue"/>
#         <line x1="400" y1="250" x2="500" y2="250" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="500" y1="250" x2="500.0" y2="50.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="500.0" y1="50.0" x2="300.0" y2="50.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="300.0" y1="50.0" x2="300.0" y2="250.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="300.0" y1="250.0" x2="500.0" y2="250.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/>
#         <g visibility=visible transform="rotate(360,500.0,250.0) translate(482.0, 232.0)">
# ...
